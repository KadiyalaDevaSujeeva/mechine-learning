# %%
#Decision tree - BAYES  SVM  PCA
from sklearn.datasets import load_iris
from sklearn import tree
from matplotlib import pyplot as plt
iris=load_iris()
x= iris.data
y= iris.target
clf=tree.DecisionTreeClassifier(criterion='entropy',max_depth=4,min_samples_leaf=4)
clf.fit(x,y)
fig,ax=plt.subplots(figsize=(6,6))
tree.plot_tree(clf,ax=ax,feature_names=['Sepal Length','Sepal Width','Petal Length','Petal Width'])
plt.show()

# %%
import os
os.chdir("E:\\53")
import pandas as pd
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 790           10      101             76             48      180  32.9
# 791            2      122             70             27        0  36.8
# 792            5      121             72             23      112  26.2
# 793            1      126             60              0        0  30.1
# 794            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x=df[['Glucose','BloodPressure','SkinThickness','BMI','Age']]
y=df['Outcome']

# %%
from sklearn import tree
from matplotlib import pyplot as plt
clf=tree.DecisionTreeClassifier(criterion='entropy',max_depth=7,min_samples_leaf=4)
clf.fit(x,y)
fig,ax=plt.subplots(figsize=(70,20))
tree.plot_tree(clf,ax=ax,feature_names=['Glucose','BloodPressure','SkinThickness','BMI','Age'])
plt.show()

# %%
x.head(2)
# Out:
#    Glucose  BloodPressure  SkinThickness   BMI  Age
# 0      148             72             35  33.6   50
# 1       85             66             29  26.6   31

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1)

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, min_samples_leaf=4)

# %%
y_pred=clf.predict(x_test)
from sklearn import metrics
print(metrics.accuracy_score(y_test,y_pred)*100)
# Out:
# 69.18238993710692

# %%
import warnings
warnings.filterwarnings("ignore")
clf.predict([[122,70,27,36.8,27]])
# Out:
# array([0], dtype=int64)

# %%
from sklearn.svm import SVC
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x=df.drop(['Id','Species'],axis=1)
y=df['Species']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
svc=SVC(random_state=101)
svc.fit(x_train,y_train)
print("test score:",svc.score(x_test,y_test))
# Out:
# test score: 1.0

# %%
import os
os.chdir("E:\\53")
import pandas as pd
df=pd.read_csv('iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
x=df.drop(['Id','Species'],axis=1)
y=df['Species']

# %%
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
knn=KNeighborsClassifier(n_neighbors=12)
knn.fit(x_train,y_train)
#make a predicyion for an example of an out-of
knn.predict([[2.1,8.9,5.6,4.0]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
y_pred=knn.predict(x_test)
print(metrics.accuracy_score(y_test,y_pred)*100)
# Out:
# 93.33333333333333

# %%
from sklearn import preprocessing
scaler=preprocessing.StandardScaler()
scaled_data=pd.DataFrame(scaler.fit_transform(x))#scaling the data
scaled_data.columns=['sl','sw','pl','pw']
scaled_data
# Out:
#            sl        sw        pl        pw
# 0   -0.900681  1.032057 -1.341272 -1.312977
# 1   -1.143017 -0.124958 -1.341272 -1.312977
# 2   -1.385353  0.337848 -1.398138 -1.312977
# 3   -1.506521  0.106445 -1.284407 -1.312977
# 4   -1.021849  1.263460 -1.341272 -1.312977
# ..        ...       ...       ...       ...
# 145  1.038005 -0.124958  0.819624  1.447956
# 146  0.553333 -1.281972  0.705893  0.922064
# 147  0.795669 -0.124958  0.819624  1.053537
# 148  0.432165  0.800654  0.933356  1.447956
# 149  0.068662 -0.124958  0.762759  0.790591
#
# [150 rows x 4 columns]

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(scaled_data,y,test_size=0.4,random_state=5)
print(x.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (150, 4)
# (120,)
# (30, 4)
# (30,)

# %%
nn=KNeighborsClassifier(n_neighbors=12)
knn.fit(x_train1,y_train1)
knn.predict([[2.1,8.9,5.6,4.0]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
y_pred=knn.predict(x_test1)
print(metrics.accuracy_score(y_test1,y_pred)*100)
# Out:
# 95.0

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica'],
#       dtype=object)

# %%
pca=PCA(n_components=4)
pca.fit(scaled_data)
data_pca=pca.transform(scaled_data)
data_pca=pd.DataFrame(data_pca,columns=['pc1','pc2','pc3','pc4'])
data_pca.head()
# Out:
#         pc1       pc2       pc3       pc4
# 0 -2.264542  0.505704 -0.121943 -0.023073
# 1 -2.086426 -0.655405 -0.227251 -0.103208
# 2 -2.367950 -0.318477  0.051480 -0.027825
# 3 -2.304197 -0.575368  0.098860  0.066311
# 4 -2.388777  0.674767  0.021428  0.037397

# %%
x_train2,x_test2,y_train2,y_test2=train_test_split(data_pca,y,test_size=0.4,random_state=5)
print(x.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (150, 4)
# (120,)
# (30, 4)
# (30,)

# %%
nn=KNeighborsClassifier(n_neighbors=12)
knn.fit(x_train2,y_train2)
knn.predict([[2.1,8.9,5.6,4.0]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
y_pred=knn.predict(x_test2)
print(metrics.accuracy_score(y_test2,y_pred)*100)
# Out:
# 95.0
